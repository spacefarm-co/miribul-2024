# %%
# 클라우드 런에서 돌려야함

# %%
import os
import time
import mlflow
import random
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV, KFold, cross_val_predict  
import optuna
from optuna.integration import MLflowCallback
import joblib
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2024-08-07 04:50:51.670717: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-07 04:50:52.673570: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/lib/x86_64-linux-gnu/:/opt/conda/lib
# 2024-08-07 04:50:52.673707: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/lib/x86_64-linux-gnu/:/opt/conda/lib
# 2024-08-07 04:50:52.673720: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
seed = 42

# %%
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# MASE
def mean_absolute_scaled_error(y_true, y_pred):
    n = len(y_true)

    # Calculate MAE of the forecasts
    mae_forecast = np.mean(np.abs(y_true - y_pred))

    # Calculate MAE of the naive forecast
    mae_naive = np.mean(np.abs(np.diff(y_true)))  # Diff calculates y_i - y_{i-1}

    # Ensure denominator is not zero
    if mae_naive == 0:
        return np.inf  # Return infinity if naive MAE is zero

    return mae_forecast / mae_naive

# %%
merge_B_ip = pd.read_csv('./data/merge_B_ip.csv', encoding = 'cp949')
merge_C_ip = pd.read_csv('./data/merge_C_ip.csv', encoding = 'cp949')
merge_D_ip = pd.read_csv('./data/merge_D_ip.csv', encoding = 'cp949')
merge_E_ip = pd.read_csv('./data/merge_E_ip.csv', encoding = 'cp949')

# %%
df_merged = pd.concat([merge_B_ip,merge_C_ip,merge_D_ip,merge_E_ip])

# %%
cols = ['Stem Diameter', 'Petiole Length','Leaf Count', 'Leaf Length', 'Leaf Width', 'Fruit Count',
       'Plant Height', 'Final Inflorescence Order','Inflorescence Flower Count', 'supplyEC', 'supplyPH', 'innerCO2',
       'innerHum', 'innerTemp', 'innerSolar', 'Survey Date']

# %%
df_merged = df_merged[cols]

# %%
df_merged['Survey Date'] = pd.to_datetime(df_merged['Survey Date'], format='%Y-%m-%d %H:%M')
df_merged.set_index('Survey Date', inplace=True)

# %%
df_merged.dropna(inplace=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 171897 entries, 2023-10-06 00:00:00 to 2024-04-26 00:00:00
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Stem Diameter               171897 non-null  float64
#  1   Petiole Length              171897 non-null  float64
#  2   Leaf Count                  171897 non-null  float64
#  3   Leaf Length                 171897 non-null  float64
#  4   Leaf Width                  171897 non-null  float64
#  5   Fruit Count                 171897 non-null  int64
#  6   Plant Height                171897 non-null  float64
#  7   Final Inflorescence Order   171897 non-null  int64
#  8   Inflorescence Flower Count  171897 non-null  int64
#  9   supplyEC                    171897 non-null  float64
#  10  supplyPH                    171897 non-null  float64
#  11  innerCO2                    171897 non-null  float64
#  12  innerHum                    171897 non-null  float64
#  13  innerTemp                   171897 non-null  float64
#  14  innerSolar                  171897 non-null  float64
# dtypes: float64(12), int64(3)
# memory usage: 21.0 MB

# %%
train, test = train_test_split(df_merged, test_size=0.2, shuffle=False)

# %%
scaler = StandardScaler()
train = scaler.fit_transform(train)
test = scaler.transform(test)

# %%
x_train = train[:,9:]
y_train = train[:,:9]
x_test = test[:,9:]
y_test = test[:,:9]

# %%
# tuning machine learning models

# %%
# bagging regressor

# %%
# parameter range from literature reviews
params = {
    'n_estimators': (100,200,500),
    'max_samples' : (0.7, 0.8, 0.9, 1.0)
}

# %%
model = BaggingRegressor()

finder = RandomizedSearchCV(
    estimator=model,
    param_distributions=params,
    scoring='r2',
    refit=True,
    cv=TimeSeriesSplit(n_splits=5),  # change this to the splitter subject to test
    return_train_score=True
    )

finder.fit(X_train, Y_train)

best_params = finder.best_params_
best_score = round(finder.best_score_,4)

# %%
# xgb regressor

# %%
# parameter range from literature reviews
params = {
    'n_estimators': (50, 100, 150),
    'max_depth': (3, 6, 9),
    'learning_rate':(0.01, 0.1, 0.3, 0.5),
    'gamma' :(5, 7, 10)
}

model = XGBRegressor()

finder = RandomizedSearchCV(
    estimator=model,
    param_distributions=params,
    scoring='r2',
    refit=True,
    cv=TimeSeriesSplit(n_splits=5),  # change this to the splitter subject to test
    return_train_score=True
    )

start_time = time.time()
finder.fit(X_train, Y_train)
print("--- %s seconds ---" %(time.time()- start_time))

best_params = finder.best_params_
best_score = round(finder.best_score_,4)

# %%
# --- Set MLflow Tracking URI ---
mlflow.set_tracking_uri("https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app")  # Replace with your server details
# http://<username>:<password>@<your_mlflow_server_host>:<port>

def optimize_xgboost(x_train, y_train, n_trials=100, experiment_name="XGBoost_Hyperparam_Tuning", n_splits=5):
    """Optimize XGBoost hyperparameters using Optuna, log results to MLflow server, and register the best model."""

    mlflow.set_experiment(experiment_name)  
    mlflow_callback = MLflowCallback(tracking_uri=mlflow.get_tracking_uri())

    def objective(trial):
        with mlflow.start_run(nested=True):  # Create nested runs for each Optuna trial
            params = {
                'n_estimators': trial.suggest_int('n_estimators', 50, 100, step=50),
                # 'max_depth': trial.suggest_int('max_depth', 3, 11, step=2),
                # 'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True), # Log scale for learning rate
                # 'gamma': trial.suggest_float('gamma', 0, 2),
                # 'subsample': trial.suggest_float('subsample', 0.6, 1.0),
                # 'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
            }

            model = xgb.XGBRegressor(**params)
            cv = KFold(n_splits=n_splits, shuffle=False)  # Blocked cross-validation
            y_pred = cross_val_predict(model, x_train, y_train, cv=cv, n_jobs=-1) # <-- Use cross_val_predict

            mse = mean_squared_error(y_train, y_pred)
            rmse = np.sqrt(mse)
            r2 = r2_score(y_train, y_pred)
            mase = mean_absolute_scaled_error(y_train, y_pred)

            

            # Log params and metrics to MLflow
            mlflow.log_params(params)
            mlflow.log_metrics({
                "mse": mse,
                "rmse": rmse,
                "r2": r2,
                "mase": mase
            })

            return rmse
        
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials, callbacks=[mlflow_callback])

    # Get best parameters and train the final model
    with mlflow.start_run(run_name="best_model"):
        best_params = study.best_params
        best_model = xgb.XGBRegressor(**best_params)
        best_model.fit(x_train, y_train)
        
        y_pred_best = best_model.predict(x_train)
        mse_best = mean_squared_error(y_train, y_pred_best)
        rmse_best = np.sqrt(mse_best)
        r2_best = r2_score(y_train, y_pred_best)
        mase_best = mean_absolute_scaled_error(y_train, y_pred_best)
        
        # Log metrics for the best model
        mlflow.log_params(best_params)
        mlflow.log_metrics({
            "best_mse": mse_best,
            "best_rmse": rmse_best,
            "best_r2": r2_best,
            "best_mase": mase_best
        })

        # Log the best model with MLflow
        mlflow.xgboost.log_model(best_model, "xgboost_model")

        return best_params, study.best_value


# --- Call the function to start the tuning process ---
best_params, best_score = optimize_xgboost(x_train, y_train, experiment_name="xbg_hp_tune_test_0807")
# Out:
# 2024/08/07 04:51:46 INFO mlflow.tracking.fluent: Experiment with name 'xbg_hp_tune_test_0807' does not exist. Creating a new experiment.
# [I 2024-08-07 04:51:46,930] A new study created in memory with name: no-name-3b870aab-1803-4d80-9e1c-b7fe9987d30f
# 2024/08/07 04:52:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run useful-penguin-103 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/3/runs/2c981189606e4911b2de515d76c116c5.
# 2024/08/07 04:52:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/3.
# [I 2024-08-07 04:52:05,585] Trial 0 finished with value: 0.7923563840053057 and parameters: {'n_estimators': 100}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:52:05 INFO mlflow.tracking.fluent: Experiment with name 'no-name-3b870aab-1803-4d80-9e1c-b7fe9987d30f' does not exist. Creating a new experiment.
# 2024/08/07 04:52:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run 0 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/53c8619c7d6a4fa6afd4ee5a4243e3b6.
# 2024/08/07 04:52:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:52:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run likeable-mule-994 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/8d83299e75a349509a5cf3f1a4341fc8.
# 2024/08/07 04:52:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:52:22,366] Trial 1 finished with value: 0.7923563840053057 and parameters: {'n_estimators': 100}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:52:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run 1 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/70d3db2dfbc1457192c22e5ca47f4552.
# 2024/08/07 04:52:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:52:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run gregarious-goose-531 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/bf87e13eb6d644bb9737f25ef27a08c8.
# 2024/08/07 04:52:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:52:39,075] Trial 2 finished with value: 0.7923563840053057 and parameters: {'n_estimators': 100}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:52:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run 2 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/8000040245534f82881b6ea7bf202169.
# 2024/08/07 04:52:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:52:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run persistent-ray-243 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/f14757de3bbf4b8eb32ffa30f22531e5.
# 2024/08/07 04:52:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:52:48,218] Trial 3 finished with value: 0.8199098770996657 and parameters: {'n_estimators': 50}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:52:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run 3 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/1a2fb63e31ad469e8accfdabf5f29f48.
# 2024/08/07 04:52:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:52:57 INFO mlflow.tracking._tracking_service.client: 🏃 View run placid-fowl-413 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/618d802f26c04fb7bb9e285fae7274f9.
# 2024/08/07 04:52:57 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:52:57,211] Trial 4 finished with value: 0.8199098770996657 and parameters: {'n_estimators': 50}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:52:57 INFO mlflow.tracking._tracking_service.client: 🏃 View run 4 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/b3cfe24630524ca6b3a9756eb1dfc935.
# 2024/08/07 04:52:57 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:53:14 INFO mlflow.tracking._tracking_service.client: 🏃 View run bright-kit-271 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/7e939679f74f4e7c967b636e0b57bc0a.
# 2024/08/07 04:53:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:53:14,865] Trial 5 finished with value: 0.7923563840053057 and parameters: {'n_estimators': 100}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:53:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run 5 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/6b2a741ede08482591c80b579eaaf225.
# 2024/08/07 04:53:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:53:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run bemused-yak-833 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/35b51d65c8ee483190e0601444fc6aec.
# 2024/08/07 04:53:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:53:23,863] Trial 6 finished with value: 0.8199098770996657 and parameters: {'n_estimators': 50}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:53:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run 6 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/6525f45aa5834f6d9b0559554d764c0b.
# 2024/08/07 04:53:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:53:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run glamorous-lark-592 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/f76faca15f4a4dfaaeb9a2de5946696d.
# 2024/08/07 04:53:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:53:40,628] Trial 7 finished with value: 0.7923563840053057 and parameters: {'n_estimators': 100}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:53:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run 7 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/277c9642fd094ce49b09ce6beb6bcd72.
# 2024/08/07 04:53:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:53:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run painted-cat-490 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/01f78ad8e6534693bd8e4754e960ad77.
# 2024/08/07 04:53:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:53:49,556] Trial 8 finished with value: 0.8199098770996657 and parameters: {'n_estimators': 50}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:53:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run 8 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/3d31cc8fa01547538662dbc9829bbbf1.
# 2024/08/07 04:53:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:53:58 INFO mlflow.tracking._tracking_service.client: 🏃 View run bedecked-koi-865 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/b4fabdee68324179aef9405b54d367d2.
# 2024/08/07 04:53:58 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:53:58,468] Trial 9 finished with value: 0.8199098770996657 and parameters: {'n_estimators': 50}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:53:58 INFO mlflow.tracking._tracking_service.client: 🏃 View run 9 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/f9f0bbc3988848de8f9efb66a20b8e24.
# 2024/08/07 04:53:58 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:54:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run loud-mole-459 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/4a0129a404b14668a1404a1a9f90512d.
# 2024/08/07 04:54:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:54:16,080] Trial 10 finished with value: 0.7923563840053057 and parameters: {'n_estimators': 100}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:54:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run 10 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/f035ec2e6b3f4ef58f166d6a7976dd0b.
# 2024/08/07 04:54:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:54:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run victorious-fowl-959 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/6b0e528118654a46a2137fb788b4e094.
# 2024/08/07 04:54:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:54:32,734] Trial 11 finished with value: 0.7923563840053057 and parameters: {'n_estimators': 100}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:54:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run 11 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/72e0371c95af4b92be90f9f0a32a271a.
# 2024/08/07 04:54:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:54:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run righteous-kit-455 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/853d9da4b54f455c9bcf77308489eed1.
# 2024/08/07 04:54:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:54:49,640] Trial 12 finished with value: 0.7923563840053057 and parameters: {'n_estimators': 100}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:54:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run 12 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/68bb5c48858948a1a4524063fab2d83b.
# 2024/08/07 04:54:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:55:06 INFO mlflow.tracking._tracking_service.client: 🏃 View run illustrious-snake-17 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/f4016de678a645fd861c1a6debc9e8e8.
# 2024/08/07 04:55:06 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# [I 2024-08-07 04:55:06,411] Trial 13 finished with value: 0.7923563840053057 and parameters: {'n_estimators': 100}. Best is trial 0 with value: 0.7923563840053057.
# 2024/08/07 04:55:06 INFO mlflow.tracking._tracking_service.client: 🏃 View run 13 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs/e1fb03ec927a4877a8eaefe41183448f.
# 2024/08/07 04:55:06 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4.
# 2024/08/07 04:55:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run abrasive-hen-436 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/4/runs
in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2606 try:
# -> 2607     created_json = self._do_upload(
#    2608         client,
#    2609         file_obj,
#    2610         content_type,
#    2611         size,
#    2612         num_retries,
#    2613         predefined_acl,
#    2614         if_generation_match,
#    2615         if_generation_not_match,
#    2616         if_metageneration_match,
#    2617         if_metageneration_not_match,
#    2618         timeout=timeout,
#    2619         checksum=checksum,
#    2620         retry=retry,
#    2621         command=command,
#    2622     )
#    2623     self._set_properties(created_json)
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/cloud/storage/blob.py:2413, in Blob._do_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2412 if size is not None and size <= _MAX_MULTIPART_SIZE:
# -> 2413     response = self._do_multipart_upload(
#    2414         client,
#    2415         stream,
#    2416         content_type,
#    2417         size,
#    2418         num_retries,
#    2419         predefined_acl,
#    2420         if_generation_match,
#    2421         if_generation_not_match,
#    2422         if_metageneration_match,
#    2423         if_metageneration_not_match,
#    2424         timeout=timeout,
#    2425         checksum=checksum,
#    2426         retry=retry,
#    2427         command=command,
#    2428     )
#    2429 else:
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/cloud/storage/blob.py:1926, in Blob._do_multipart_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    1922 upload._retry_strategy = _api_core_retry_to_resumable_media_retry(
#    1923     retry, num_retries
#    1924 )
# -> 1926 response = upload.transmit(
#    1927     transport, data, object_metadata, content_type, timeout=timeout
#    1928 )
#    1930 return response
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/resumable_media/requests/upload.py:153, in MultipartUpload.transmit(self, transport, data, metadata, content_type, timeout)
#     151     return result
# --> 153 return _request_helpers.wait_and_retry(
#     154     retriable_request, self._get_status_code, self._retry_strategy
#     155 )
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/resumable_media/requests/_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/resumable_media/requests/upload.py:149, in MultipartUpload.transmit.<locals>.retriable_request()
#     145 result = transport.request(
#     146     method, url, data=payload, headers=headers, timeout=timeout
#     147 )
# --> 149 self._process_response(result)
#     151 return result
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/resumable_media/_upload.py:125, in UploadBase._process_response(self, response)
#     124 self._finished = True
# --> 125 _helpers.require_status_code(response, (http.client.OK,), self._get_status_code)
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/resumable_media/_helpers.py:108, in require_status_code(response, status_codes, get_status_code, callback)
#     107         callback()
# --> 108     raise common.InvalidResponse(
#     109         response,
#     110         "Request failed with status code",
#     111         status_code,
#     112         "Expected one of",
#     113         *status_codes
#     114     )
#     115 return status_code
#
# InvalidResponse: ('Request failed with status code', 403, 'Expected one of', <HTTPStatus.OK: 200>)
#
# During handling of the above exception, another exception occurred:
#
# Forbidden                                 Traceback (most recent call last)
# Cell In[17], line 75
#      71         return best_params, study.best_value
#      74 # --- Call the function to start the tuning process ---
# ---> 75 best_params, best_score = optimize_xgboost(x_train, y_train, experiment_name="xbg_hp_tune_test_0807")
#
# Cell In[17], line 69, in optimize_xgboost(x_train, y_train, n_trials, experiment_name, n_splits)
#      61 mlflow.log_metrics({
#      62     "best_mse": mse_best,
#      63     "best_rmse": rmse_best,
#      64     "best_r2": r2_best,
#      65     "best_mase": mase_best
#      66 })
#      68 # Log the best model with MLflow
# ---> 69 mlflow.xgboost.log_model(best_model, "xgboost_model")
#      71 return best_params, study.best_value
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/mlflow/xgboost/__init__.py:264, in log_model(xgb_model, artifact_path, conda_env, code_paths, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, model_format, metadata, **kwargs)
#     222 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name=FLAVOR_NAME))
#     223 def log_model(
#     224     xgb_model,
#    (...)
#     236     **kwargs,
#     237 ):
#     238     """Log an XGBoost model as an MLflow artifact for the current run.
#     239
#     240     Args:
#    (...)
#     262         metadata of the logged model.
#     263     """
# --> 264     return Model.log(
#     265         artifact_path=artifact_path,
#     266         flavor=mlflow.xgboost,
#     267         registered_model_name=registered_model_name,
#     268         xgb_model=xgb_model,
#     269         model_format=model_format,
#     270         conda_env=conda_env,
#     271         code_paths=code_paths,
#     272         signature=signature,
#     273         input_example=input_example,
#     274         await_registration_for=await_registration_for,
#     275         pip_requirements=pip_requirements,
#     276         extra_pip_requirements=extra_pip_requirements,
#     277         metadata=metadata,
#     278         **kwargs,
#     279     )
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/mlflow/models/model.py:714, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, **kwargs)
#     710 if mlflow_model.signature is None and (
#     711     tracking_uri == "databricks" or get_uri_scheme(tracking_uri) == "databricks"
#     712 ):
#     713     _logger.warning(_LOG_MODEL_MISSING_SIGNATURE_WARNING)
# --> 714 mlflow.tracking.fluent.log_artifacts(local_path, mlflow_model.artifact_path, run_id)
#     716 # if the model_config kwarg is passed in, then log the model config as an params
#     717 if model_config := kwargs.get("model_config"):
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/mlflow/tracking/fluent.py:1147, in log_artifacts(local_dir, artifact_path, run_id)
#    1115 """
#    1116 Log all the contents of a local directory as artifacts of the run. If no run is active,
#    1117 this method will create a new active run.
#    (...)
#    1144             mlflow.log_artifacts(tmp_dir, artifact_path="states")
#    1145 """
#    1146 run_id = run_id or _get_or_start_run().info.run_id
# -> 1147 MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/mlflow/tracking/client.py:1962, in MlflowClient.log_artifacts(self, run_id, local_dir, artifact_path)
#    1916 def log_artifacts(
#    1917     self, run_id: str, local_dir: str, artifact_path: Optional[str] = None
#    1918 ) -> None:
#    1919     """Write a directory of files to the remote ``artifact_uri``.
#    1920
#    1921     Args:
#    (...)
#    1960
#    1961     """
# -> 1962     self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:843, in TrackingServiceClient.log_artifacts(self, run_id, local_dir, artifact_path)
#     835 def log_artifacts(self, run_id, local_dir, artifact_path=None):
#     836     """Write a directory of files to the remote ``artifact_uri``.
#     837
#     838     Args:
#    (...)
#     841
#     842     """
# --> 843     self._get_artifact_repo(run_id).log_artifacts(local_dir, artifact_path)
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/mlflow/store/artifact/gcs_artifact_repo.py:106, in GCSArtifactRepository.log_artifacts(self, local_dir, artifact_path)
#     104 for f in filenames:
#     105     path = posixpath.join(upload_path, f)
# --> 106     gcs_bucket.blob(path, chunk_size=self._GCS_UPLOAD_CHUNK_SIZE).upload_from_filename(
#     107         os.path.join(root, f), timeout=self._GCS_DEFAULT_TIMEOUT
#     108     )
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/cloud/storage/blob.py:2929, in Blob.upload_from_filename(self, filename, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    2807 def upload_from_filename(
#    2808     self,
#    2809     filename,
#    (...)
#    2820     retry=DEFAULT_RETRY_IF_GENERATION_SPECIFIED,
#    2821 ):
#    2822     """Upload this blob's contents from the content of a named file.
#    2823
#    2824     The content type of the upload will be determined in order
#    (...)
#    2926         are respected.
#    2927     """
# -> 2929     self._handle_filename_and_upload(
#    2930         filename,
#    2931         content_type=content_type,
#    2932         num_retries=num_retries,
#    2933         client=client,
#    2934         predefined_acl=predefined_acl,
#    2935         if_generation_match=if_generation_match,
#    2936         if_generation_not_match=if_generation_not_match,
#    2937         if_metageneration_match=if_metageneration_match,
#    2938         if_metageneration_not_match=if_metageneration_not_match,
#    2939         timeout=timeout,
#    2940         checksum=checksum,
#    2941         retry=retry,
#    2942     )
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/cloud/storage/blob.py:2799, in Blob._handle_filename_and_upload(self, filename, content_type, *args, **kwargs)
#    2797 with open(filename, "rb") as file_obj:
#    2798     total_bytes = os.fstat(file_obj.fileno()).st_size
# -> 2799     self._prep_and_do_upload(
#    2800         file_obj,
#    2801         content_type=content_type,
#    2802         size=total_bytes,
#    2803         *args,
#    2804         **kwargs,
#    2805     )
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/cloud/storage/blob.py:2625, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2623     self._set_properties(created_json)
#    2624 except resumable_media.InvalidResponse as exc:
# -> 2625     _raise_from_invalid_response(exc)
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/google/cloud/storage/blob.py:4791, in _raise_from_invalid_response(error)
#    4787     error_message = str(error)
#    4789 message = f"{response.request.method} {response.request.url}: {error_message}"
# -> 4791 raise exceptions.from_http_status(response.status_code, message, response=response)
#
# Forbidden: 403 POST https://storage.googleapis.com/upload/storage/v1/b/smart-ai-contest-bucket/o?uploadType=multipart: {
#   "error": {
#     "code": 403,
#     "message": "390653291492-compute@developer.gserviceaccount.com does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).",
#     "errors": [
#       {
#         "message": "390653291492-compute@developer.gserviceaccount.com does not have storage.objects.create access to the Google Cloud Storage object. Permission 'storage.objects.create' denied on resource (or it may not exist).",
#         "domain": "global",
#         "reason": "forbidden"
#       }
#     ]
#   }
# }
# : ('Request failed with status code', 403, 'Expected one of', <HTTPStatus.OK: 200>)

# %%
# tuning deep learning models
