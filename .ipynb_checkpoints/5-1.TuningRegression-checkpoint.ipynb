# %%
# 클라우드 런에서 돌려야함

# %%
import os
import time
import mlflow
import random
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV, KFold, cross_val_predict  
import optuna
from optuna.integration import MLflowCallback
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
seed = 42

# %%
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# MASE
def mean_absolute_scaled_error(y_true, y_pred):
    n = len(y_true)

    # Calculate MAE of the forecasts
    mae_forecast = np.mean(np.abs(y_true - y_pred))

    # Calculate MAE of the naive forecast
    mae_naive = np.mean(np.abs(np.diff(y_true)))  # Diff calculates y_i - y_{i-1}

    # Ensure denominator is not zero
    if mae_naive == 0:
        return np.inf  # Return infinity if naive MAE is zero

    return mae_forecast / mae_naive

# %%
merge_B_ip = pd.read_csv('./data/merge_B_ip.csv', encoding = 'cp949')
merge_C_ip = pd.read_csv('./data/merge_C_ip.csv', encoding = 'cp949')
merge_D_ip = pd.read_csv('./data/merge_D_ip.csv', encoding = 'cp949')
merge_E_ip = pd.read_csv('./data/merge_E_ip.csv', encoding = 'cp949')

# %%
df_merged = pd.concat([merge_B_ip,merge_C_ip,merge_D_ip,merge_E_ip])

# %%
cols = ['Stem Diameter', 'Petiole Length','Leaf Count', 'Leaf Length', 'Leaf Width', 'Fruit Count',
       'Plant Height', 'Final Inflorescence Order','Inflorescence Flower Count', 'supplyEC', 'supplyPH', 'innerCO2',
       'innerHum', 'innerTemp', 'innerSolar', 'Survey Date']

# %%
df_merged = df_merged[cols]

# %%
df_merged['Survey Date'] = pd.to_datetime(df_merged['Survey Date'], format='%Y-%m-%d %H:%M')
df_merged.set_index('Survey Date', inplace=True)

# %%
df_merged.dropna(inplace=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 171897 entries, 2023-10-06 00:00:00 to 2024-04-26 00:00:00
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Stem Diameter               171897 non-null  float64
#  1   Petiole Length              171897 non-null  float64
#  2   Leaf Count                  171897 non-null  float64
#  3   Leaf Length                 171897 non-null  float64
#  4   Leaf Width                  171897 non-null  float64
#  5   Fruit Count                 171897 non-null  int64
#  6   Plant Height                171897 non-null  float64
#  7   Final Inflorescence Order   171897 non-null  int64
#  8   Inflorescence Flower Count  171897 non-null  int64
#  9   supplyEC                    171897 non-null  float64
#  10  supplyPH                    171897 non-null  float64
#  11  innerCO2                    171897 non-null  float64
#  12  innerHum                    171897 non-null  float64
#  13  innerTemp                   171897 non-null  float64
#  14  innerSolar                  171897 non-null  float64
# dtypes: float64(12), int64(3)
# memory usage: 21.0 MB

# %%
train, test = train_test_split(df_merged, test_size=0.2, shuffle=False)

# %%
scaler = StandardScaler()
train = scaler.fit_transform(train)
test = scaler.transform(test)

# %%
x_train = train[:,9:]
y_train = train[:,:9]
x_test = test[:,9:]
y_test = test[:,:9]

# %%
# tuning machine learning models

# %%
# bagging regressor

# %%
# parameter range from literature reviews
params = {
    'n_estimators': (100,200,500),
    'max_samples' : (0.7, 0.8, 0.9, 1.0)
}

# %%
model = BaggingRegressor()

finder = RandomizedSearchCV(
    estimator=model,
    param_distributions=params,
    scoring='r2',
    refit=True,
    cv=TimeSeriesSplit(n_splits=5),  # change this to the splitter subject to test
    return_train_score=True
    )

finder.fit(X_train, Y_train)

best_params = finder.best_params_
best_score = round(finder.best_score_,4)

# %%
# xgb regressor

# %%
# parameter range from literature reviews
params = {
    'n_estimators': (50, 100, 150),
    'max_depth': (3, 6, 9),
    'learning_rate':(0.01, 0.1, 0.3, 0.5),
    'gamma' :(5, 7, 10)
}

model = XGBRegressor()

finder = RandomizedSearchCV(
    estimator=model,
    param_distributions=params,
    scoring='r2',
    refit=True,
    cv=TimeSeriesSplit(n_splits=5),  # change this to the splitter subject to test
    return_train_score=True
    )

start_time = time.time()
finder.fit(X_train, Y_train)
print("--- %s seconds ---" %(time.time()- start_time))

best_params = finder.best_params_
best_score = round(finder.best_score_,4)

# %%
# --- Set MLflow Tracking URI ---
mlflow.set_tracking_uri("https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app")  # Replace with your server details
# http://<username>:<password>@<your_mlflow_server_host>:<port>

def optimize_xgboost(x_train, y_train, n_trials=100, experiment_name="XGBoost_Hyperparam_Tuning", n_splits=5):
    """Optimize XGBoost hyperparameters using Optuna, log results to MLflow server, and register the best model."""

    mlflow.set_experiment(experiment_name)  
    mlflow_callback = MLflowCallback(tracking_uri=mlflow.get_tracking_uri())

    def objective(trial):
        with mlflow.start_run(nested=True):  # Create nested runs for each Optuna trial
            params = {
                'n_estimators': trial.suggest_int('n_estimators', 50, 200, step=50),
                # 'max_depth': trial.suggest_int('max_depth', 3, 11, step=2),
                # 'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True), # Log scale for learning rate
                # 'gamma': trial.suggest_float('gamma', 0, 2),
                # 'subsample': trial.suggest_float('subsample', 0.6, 1.0),
                # 'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
            }

            model = xgb.XGBRegressor(**params)
            cv = KFold(n_splits=n_splits, shuffle=False)  # Blocked cross-validation
            y_pred = cross_val_predict(model, x_train, y_train, cv=cv, n_jobs=-1) # <-- Use cross_val_predict

            mse = mean_squared_error(y_train, y_pred)
            rmse = np.sqrt(mse)
            r2 = r2_score(y_train, y_pred)
            mase = mean_absolute_scaled_error(y_train, y_pred)

            

            # Log params and metrics to MLflow
            mlflow.log_params(params)
            mlflow.log_metrics({
                "mse": mse,
                "rmse": rmse,
                "r2": r2,
                "mase": mase
            })

            return rmse
        
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials, callbacks=[mlflow_callback])

    # Get best parameters and train the final model
    with mlflow.start_run(run_name="best_model"):
        best_params = study.best_params
        best_model = xgb.XGBRegressor(**best_params)
        best_model.fit(x_train, y_train)
        
        y_pred_best = best_model.predict(x_train)
        mse_best = mean_squared_error(y_train, y_pred_best)
        rmse_best = np.sqrt(mse_best)
        r2_best = r2_score(y_train, y_pred_best)
        mase_best = mean_absolute_scaled_error(y_train, y_pred_best)
        
        # Log metrics for the best model
        mlflow.log_params(best_params)
        mlflow.log_metrics({
            "best_mse": mse_best,
            "best_rmse": rmse_best,
            "best_r2": r2_best,
            "best_mase": mase_best
        })

        # Log the best model with MLflow
        mlflow.xgboost.log_model(best_model, "xgboost_model")

        return best_params, study.best_value


# --- Call the function to start the tuning process ---
best_params, best_score = optimize_xgboost(x_train, y_train)
# Out:
# [I 2024-08-07 03:30:05,523] A new study created in memory with name: no-name-5a255508-6cac-4a7d-87c3-c61b1b8ef597
# 2024/08/07 03:30:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run mercurial-ray-979 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/1/runs/bc22dc6d79bd402db760f6437e091460.
# 2024/08/07 03:30:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/1.
# [I 2024-08-07 03:30:22,762] Trial 0 finished with value: 0.7727764267784701 and parameters: {'n_estimators': 50, 'max_depth': 9, 'learning_rate': 0.18040378993347958, 'gamma': 0.6992627100810342, 'subsample': 0.784844038680522, 'colsample_bytree': 0.9324119781595585}. Best is trial 0 with value: 0.7727764267784701.
# 2024/08/07 03:30:22 INFO mlflow.tracking.fluent: Experiment with name 'no-name-5a255508-6cac-4a7d-87c3-c61b1b8ef597' does not exist. Creating a new experiment.
# 2024/08/07 03:30:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run 0 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/ef30cad856c74b699dfdf320b7618fe4.
# 2024/08/07 03:30:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:30:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run gregarious-rat-896 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/1db720154b9c42e39613e07425774290.
# 2024/08/07 03:30:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:30:53,547] Trial 1 finished with value: 0.8508981485530793 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.01723919649650933, 'gamma': 1.6370612038410437, 'subsample': 0.6094686794138264, 'colsample_bytree': 0.7818265348088109}. Best is trial 0 with value: 0.7727764267784701.
# 2024/08/07 03:30:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run 1 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/4fb99cf70e3e4f5ba302193e5b8e4a6e.
# 2024/08/07 03:30:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:31:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run classy-worm-925 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/1348b64f62494594945013ac47d54593.
# 2024/08/07 03:31:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:31:10,183] Trial 2 finished with value: 0.923810661085637 and parameters: {'n_estimators': 50, 'max_depth': 9, 'learning_rate': 0.010068148520228602, 'gamma': 1.5196415508692658, 'subsample': 0.7045700944207623, 'colsample_bytree': 0.7405661506233908}. Best is trial 0 with value: 0.7727764267784701.
# 2024/08/07 03:31:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run 2 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/65ceefc176784ae498188c789f3d307f.
# 2024/08/07 03:31:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:31:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run learned-gnat-74 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/31c58a40a08147789d7a74cfd8c02175.
# 2024/08/07 03:31:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:31:30,487] Trial 3 finished with value: 0.7476826358721591 and parameters: {'n_estimators': 100, 'max_depth': 11, 'learning_rate': 0.1807509207140866, 'gamma': 0.9281423598947414, 'subsample': 0.8280190796320055, 'colsample_bytree': 0.9510074507964272}. Best is trial 3 with value: 0.7476826358721591.
# 2024/08/07 03:31:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run 3 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/35c75927c3e247318ce688c3ae215057.
# 2024/08/07 03:31:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:31:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run welcoming-cod-312 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/532f70b07c4844d59ebb3fac9c13a118.
# 2024/08/07 03:31:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:31:52,423] Trial 4 finished with value: 0.872741200492807 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.1786657907189479, 'gamma': 1.5327964068629125, 'subsample': 0.7692568389841922, 'colsample_bytree': 0.719605288179352}. Best is trial 3 with value: 0.7476826358721591.
# 2024/08/07 03:31:52 INFO mlflow.tracking._tracking_service.client: 🏃 View run 4 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/267ae0fe52074502befda7b0f888b9f8.
# 2024/08/07 03:31:52 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:32:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run salty-auk-869 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/2b5d3e616dc140ec889a3e36ea8cc001.
# 2024/08/07 03:32:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:32:22,853] Trial 5 finished with value: 0.8760571486482276 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.025232197839900005, 'gamma': 1.2106898729015656, 'subsample': 0.9224424517043721, 'colsample_bytree': 0.8544470648082669}. Best is trial 3 with value: 0.7476826358721591.
# 2024/08/07 03:32:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run 5 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/89f2043aeb9a40e7a354a19c1aa1d58d.
# 2024/08/07 03:32:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:32:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run salty-auk-609 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/92263e95bd7f4f4fbd0963f93e0c635c.
# 2024/08/07 03:32:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:32:55,160] Trial 6 finished with value: 0.8938466176926622 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.016116380193020946, 'gamma': 0.336599105281401, 'subsample': 0.6536362631039138, 'colsample_bytree': 0.6319904735042282}. Best is trial 3 with value: 0.7476826358721591.
# 2024/08/07 03:32:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run 6 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/dee77f2e2e504dd68fe084e2ef582dac.
# 2024/08/07 03:32:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:33:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run delicate-colt-744 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/058b3be66df6461e833ce019a28d500f.
# 2024/08/07 03:33:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:33:36,309] Trial 7 finished with value: 0.720525293791253 and parameters: {'n_estimators': 150, 'max_depth': 11, 'learning_rate': 0.13831432862089965, 'gamma': 0.21013468903905608, 'subsample': 0.9603938910369809, 'colsample_bytree': 0.9604849901161785}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:33:36 INFO mlflow.tracking._tracking_service.client: 🏃 View run 7 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/e32e1c934bd34362afefbbf12bef9351.
# 2024/08/07 03:33:36 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:33:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run inquisitive-elk-36 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/0b66a16bf5fd47e4be04f547312f56fc.
# 2024/08/07 03:33:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:33:48,781] Trial 8 finished with value: 0.9359950556563347 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.016584268477775277, 'gamma': 0.8424421510271543, 'subsample': 0.6820707558899695, 'colsample_bytree': 0.7462519167071103}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:33:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run 8 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/46103d5dc74649c6877dac11432c231c.
# 2024/08/07 03:33:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:34:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run debonair-shrike-4 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/a37cec0f21ff44209d500020979bae0d.
# 2024/08/07 03:34:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:34:30,858] Trial 9 finished with value: 0.8176581612858113 and parameters: {'n_estimators': 100, 'max_depth': 11, 'learning_rate': 0.023397021412576758, 'gamma': 0.37262218185674345, 'subsample': 0.7831698234298381, 'colsample_bytree': 0.6655891776776406}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:34:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run 9 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/31c8101af1fc43f094998d5c7eb31455.
# 2024/08/07 03:34:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:35:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run spiffy-bird-763 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/f10628f984004db481c5085df10358ef.
# 2024/08/07 03:35:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:35:01,906] Trial 10 finished with value: 0.8026449844084722 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.0779581296849794, 'gamma': 0.06856208790857488, 'subsample': 0.9886310211265804, 'colsample_bytree': 0.9986552957028481}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:35:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run 10 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/75c69d6aea3f400bb695e133d45309c5.
# 2024/08/07 03:35:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:35:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run persistent-shark-941 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/3b34536061264225a8c35b62b92135bc.
# 2024/08/07 03:35:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:35:34,530] Trial 11 finished with value: 0.755603551758287 and parameters: {'n_estimators': 150, 'max_depth': 11, 'learning_rate': 0.08497140736689104, 'gamma': 1.1098493580864448, 'subsample': 0.8867311317825323, 'colsample_bytree': 0.887516928953283}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:35:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run 11 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/b347f83cdb284959a6def83da108a159.
# 2024/08/07 03:35:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:35:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run victorious-stag-954 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/f35f94515e0142e6bc3919c5286e7009.
# 2024/08/07 03:35:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:35:59,272] Trial 12 finished with value: 0.7713707217547684 and parameters: {'n_estimators': 150, 'max_depth': 11, 'learning_rate': 0.09997980528711864, 'gamma': 1.9976502297502563, 'subsample': 0.8664153613446982, 'colsample_bytree': 0.9993740227482787}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:35:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run 12 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/fff61f43957b42ad9fe7dcfb86f52f1c.
# 2024/08/07 03:35:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:36:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run persistent-shark-584 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/6c83ffaebb0d4ee7890be1be938731af.
# 2024/08/07 03:36:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:36:42,053] Trial 13 finished with value: 0.7589099343914554 and parameters: {'n_estimators': 100, 'max_depth': 11, 'learning_rate': 0.05283990363320381, 'gamma': 0.5869665785014528, 'subsample': 0.9990572293578734, 'colsample_bytree': 0.9266736859428938}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:36:42 INFO mlflow.tracking._tracking_service.client: 🏃 View run 13 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/fcef4834d9ab4785ad3ac149e9feea2e.
# 2024/08/07 03:36:42 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:37:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run youthful-toad-415 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/4f3c0d28882b42919159972c3d745e40.
# 2024/08/07 03:37:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:37:29,368] Trial 14 finished with value: 0.7330653474467459 and parameters: {'n_estimators': 150, 'max_depth': 9, 'learning_rate': 0.12109869219710735, 'gamma': 0.015572366450301939, 'subsample': 0.8501674047034906, 'colsample_bytree': 0.840711398222233}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:37:29 INFO mlflow.tracking._tracking_service.client: 🏃 View run 14 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/7569d7ad495c44da9342ce1c510a1e85.
# 2024/08/07 03:37:29 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:37:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run calm-boar-102 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/19fbd238a4dc488eb018fdaba67363cb.
# 2024/08/07 03:37:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:37:59,673] Trial 15 finished with value: 0.7863277174505681 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.12437814981519818, 'gamma': 0.021593571578205212, 'subsample': 0.9282917584683792, 'colsample_bytree': 0.8260329339682273}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:37:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run 15 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/2d9db8a71b08474ab28fc4a60d8cd44d.
# 2024/08/07 03:37:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:38:45 INFO mlflow.tracking._tracking_service.client: 🏃 View run upbeat-lynx-648 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/20ca7f10ef5d49c58a24c2eed18cfa46.
# 2024/08/07 03:38:45 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:38:45,898] Trial 16 finished with value: 0.7768388827487547 and parameters: {'n_estimators': 150, 'max_depth': 9, 'learning_rate': 0.05441936913373944, 'gamma': 0.28612994006127423, 'subsample': 0.9495043883456049, 'colsample_bytree': 0.826707584569299}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:38:46 INFO mlflow.tracking._tracking_service.client: 🏃 View run 16 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/5a8cbcec50384606a713f69657d7fe29.
# 2024/08/07 03:38:46 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:39:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run clean-lamb-57 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/6f9fdfe34463442a802bda11219e0a29.
# 2024/08/07 03:39:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:39:30,749] Trial 17 finished with value: 0.7393019771476256 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.1253803409219229, 'gamma': 0.5104875675654406, 'subsample': 0.8401499859300925, 'colsample_bytree': 0.884156468413118}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:39:30 INFO mlflow.tracking._tracking_service.client: 🏃 View run 17 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/89e4b00ca3784ca098740b1b4351a273.
# 2024/08/07 03:39:30 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:40:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run defiant-rook-942 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/756837d296bd419fab05ed829aa6224f.
# 2024/08/07 03:40:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:40:05,041] Trial 18 finished with value: 0.8346043402129084 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.03269032402360086, 'gamma': 0.20460054324512117, 'subsample': 0.7428895076410607, 'colsample_bytree': 0.8913123437608261}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:40:05 INFO mlflow.tracking._tracking_service.client: 🏃 View run 18 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/7a3162cf477f4dcd9f60c28d976aa730.
# 2024/08/07 03:40:05 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:41:03 INFO mlflow.tracking._tracking_service.client: 🏃 View run stylish-shrew-461 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/b86076e8b40f44028b6a815bcdaf95e4.
# 2024/08/07 03:41:03 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:41:03,123] Trial 19 finished with value: 0.7266821476199055 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.12292952790108248, 'gamma': 0.046395873560376666, 'subsample': 0.9572619369799094, 'colsample_bytree': 0.7868048273811337}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:41:03 INFO mlflow.tracking._tracking_service.client: 🏃 View run 19 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/3bf3bc3549324c0280fa432a3bdad130.
# 2024/08/07 03:41:03 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:41:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run stately-owl-995 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/d83dec83cf50467db8e17d896e58823d.
# 2024/08/07 03:41:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:41:32,947] Trial 20 finished with value: 0.8458006247548554 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.07126241688496514, 'gamma': 0.5290643363069137, 'subsample': 0.959243271007314, 'colsample_bytree': 0.784543312064239}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:41:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run 20 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/11b0d3c25ac5477bad4646465b884ee2.
# 2024/08/07 03:41:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:42:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run defiant-hound-755 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/0e331e98bbb84b598e8e66b7593967fd.
# 2024/08/07 03:42:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:42:33,467] Trial 21 finished with value: 0.7319300633887661 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.10828759500434704, 'gamma': 0.04976200165272377, 'subsample': 0.8947813347402583, 'colsample_bytree': 0.6963881263452111}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:42:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run 21 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/dd0fa0eca0154e2e9094ea434651f1b7.
# 2024/08/07 03:42:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:43:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run gentle-flea-685 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/3bdef11a7055409180c712ad6dab3ba7.
# 2024/08/07 03:43:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:43:24,608] Trial 22 finished with value: 0.737660755846611 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.14292035869098813, 'gamma': 0.19008031913666862, 'subsample': 0.9018904747790644, 'colsample_bytree': 0.6450782915592443}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:43:24 INFO mlflow.tracking._tracking_service.client: 🏃 View run 22 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/d34389e5f7df498aae350f70b36bb095.
# 2024/08/07 03:43:24 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:44:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run blushing-carp-972 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/af1d7f28bacc4013a77b732c265b3fa0.
# 2024/08/07 03:44:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:44:21,337] Trial 23 finished with value: 0.7216836992227814 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.09754533031923074, 'gamma': 0.19125711325271647, 'subsample': 0.9588505391775684, 'colsample_bytree': 0.7015261289345106}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:44:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run 23 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/d6df0787ba2548799961b2dd64e0e1be.
# 2024/08/07 03:44:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:45:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run redolent-fly-141 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/4939ac06c67d4f0c8a041cb131dd9eaf.
# 2024/08/07 03:45:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:45:17,528] Trial 24 finished with value: 0.7417624796423182 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.06204220672542693, 'gamma': 0.41943713176325736, 'subsample': 0.9638716211775101, 'colsample_bytree': 0.7681893520802504}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:45:17 INFO mlflow.tracking._tracking_service.client: 🏃 View run 24 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/7b8739f11b9e491d9dab7fbfbe3f523c.
# 2024/08/07 03:45:17 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:46:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run debonair-hog-704 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/c4c0155b6f8c40fea7ae3f7e6463b746.
# 2024/08/07 03:46:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:46:28,140] Trial 25 finished with value: 0.7559488145926575 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.04178374897912551, 'gamma': 0.6999359122696316, 'subsample': 0.9305148837115422, 'colsample_bytree': 0.6043425104072122}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:46:28 INFO mlflow.tracking._tracking_service.client: 🏃 View run 25 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/b0500697df9548b699e8b1fb471ad095.
# 2024/08/07 03:46:28 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:47:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run painted-sheep-492 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/4038f5921de846e49cc6e0d6f4897459.
# 2024/08/07 03:47:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:47:21,054] Trial 26 finished with value: 0.7260333037612513 and parameters: {'n_estimators': 150, 'max_depth': 11, 'learning_rate': 0.08735054792662894, 'gamma': 0.16856320063368202, 'subsample': 0.9772436410654963, 'colsample_bytree': 0.6884387475878211}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:47:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run 26 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/9a1fa3849a61447dbb75c3f43bf9dc6c.
# 2024/08/07 03:47:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:48:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run marvelous-stag-600 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/db02c7c6b84c49779eb52ed839b73be5.
# 2024/08/07 03:48:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:48:02,649] Trial 27 finished with value: 0.7365771029827967 and parameters: {'n_estimators': 150, 'max_depth': 11, 'learning_rate': 0.09270845230261598, 'gamma': 0.21559700907578974, 'subsample': 0.9948567593095785, 'colsample_bytree': 0.6938759626781581}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:48:02 INFO mlflow.tracking._tracking_service.client: 🏃 View run 27 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/83ef3dce926c41479be1c433fd5f553e.
# 2024/08/07 03:48:02 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:49:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run carefree-deer-989 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/1bc53c74f1684d9291ae64c1ea34cadf.
# 2024/08/07 03:49:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:49:01,337] Trial 28 finished with value: 0.7546850697321349 and parameters: {'n_estimators': 150, 'max_depth': 11, 'learning_rate': 0.04098856668525158, 'gamma': 0.7137384543508618, 'subsample': 0.8742713065655849, 'colsample_bytree': 0.6753143993716043}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:49:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run 28 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/20692d2f6e7a44998fe4141c4c1b03e0.
# 2024/08/07 03:49:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:49:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run secretive-fowl-703 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/e2b7aec4656542a89637b467a7a8330e.
# 2024/08/07 03:49:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:49:21,371] Trial 29 finished with value: 0.7471515785769746 and parameters: {'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.15876968409388503, 'gamma': 0.5930993010704747, 'subsample': 0.8168465746526898, 'colsample_bytree': 0.7192528088808633}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:49:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run 29 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/542c7d8582d6478287150ad2e0ca1215.
# 2024/08/07 03:49:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:50:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run chill-hog-37 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/34219f4262fd47818033c78b5c03cc5a.
# 2024/08/07 03:50:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:50:13,266] Trial 30 finished with value: 0.7440919087182835 and parameters: {'n_estimators': 150, 'max_depth': 11, 'learning_rate': 0.06934178229465013, 'gamma': 0.43029505708054683, 'subsample': 0.9096302392939173, 'colsample_bytree': 0.6219027784554629}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:50:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run 30 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/313d3de77f604e24a8ff27c84796eed0.
# 2024/08/07 03:50:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:51:00 INFO mlflow.tracking._tracking_service.client: 🏃 View run nebulous-swan-209 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/bb067057abc344e9a6280890af3bc819.
# 2024/08/07 03:51:00 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:51:00,384] Trial 31 finished with value: 0.7294634795325112 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.14380429967473596, 'gamma': 0.13788668783986016, 'subsample': 0.9651119564175811, 'colsample_bytree': 0.7520484939907126}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:51:00 INFO mlflow.tracking._tracking_service.client: 🏃 View run 31 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/9c64dfaa67a349ec8100f234bada6a6f.
# 2024/08/07 03:51:00 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:51:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run zealous-snail-248 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/156d523c6ce949d983b234430b8d9f9a.
# 2024/08/07 03:51:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:51:48,763] Trial 32 finished with value: 0.7448875563843392 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.09630716805893177, 'gamma': 0.2526765705023267, 'subsample': 0.9436294633702264, 'colsample_bytree': 0.7924065868466577}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:51:48 INFO mlflow.tracking._tracking_service.client: 🏃 View run 32 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/161c69a9f12043fd8087c3a471fa7295.
# 2024/08/07 03:51:48 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:52:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run honorable-mole-83 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/b702b2c7ac8b462392c502dbce9411e8.
# 2024/08/07 03:52:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:52:22,057] Trial 33 finished with value: 0.7341642877430121 and parameters: {'n_estimators': 150, 'max_depth': 9, 'learning_rate': 0.19743530114532368, 'gamma': 0.1591612602844624, 'subsample': 0.9770502572723049, 'colsample_bytree': 0.7175151567305456}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:52:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run 33 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/96339af110fa4d56933dc21ef85bd2aa.
# 2024/08/07 03:52:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:52:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run unique-perch-38 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/0223ab98be4242db88d923a92ac09c6b.
# 2024/08/07 03:52:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:52:43,698] Trial 34 finished with value: 0.7543885865353377 and parameters: {'n_estimators': 50, 'max_depth': 11, 'learning_rate': 0.11599518772415758, 'gamma': 0.32394344393329444, 'subsample': 0.9370602621300635, 'colsample_bytree': 0.8128739650946998}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:52:43 INFO mlflow.tracking._tracking_service.client: 🏃 View run 34 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/6a1c53fd10dc4d03aa0fe7a981052ccf.
# 2024/08/07 03:52:43 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:52:58 INFO mlflow.tracking._tracking_service.client: 🏃 View run bouncy-donkey-1 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/e57a9380b17f4b9db4c0bd5e814eba63.
# 2024/08/07 03:52:58 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:52:58,953] Trial 35 finished with value: 0.7891616946802122 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.15431412092839653, 'gamma': 1.257357908269835, 'subsample': 0.9795585585885763, 'colsample_bytree': 0.9604421833556152}. Best is trial 7 with value: 0.720525293791253.
# 2024/08/07 03:52:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run 35 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/580e9c098b7548fe9affa8b6f5f2b754.
# 2024/08/07 03:52:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:54:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run rumbling-flea-609 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/8f9603044fbe42eeac4b86517cc2c741.
# 2024/08/07 03:54:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:54:15,655] Trial 36 finished with value: 0.719712403090776 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.08396571555319772, 'gamma': 0.1134847141849225, 'subsample': 0.9092289880886159, 'colsample_bytree': 0.6621715227553442}. Best is trial 36 with value: 0.719712403090776.
# 2024/08/07 03:54:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run 36 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/9d10969962af4d53b7acc853bbc96dc9.
# 2024/08/07 03:54:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:54:54 INFO mlflow.tracking._tracking_service.client: 🏃 View run caring-midge-389 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/72561f1f512c426c857b60bb68f93ee5.
# 2024/08/07 03:54:54 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:54:54,161] Trial 37 finished with value: 0.7511287170680685 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.0831084476085234, 'gamma': 0.8190839322627467, 'subsample': 0.9080142556072086, 'colsample_bytree': 0.6677204447586255}. Best is trial 36 with value: 0.719712403090776.
# 2024/08/07 03:54:54 INFO mlflow.tracking._tracking_service.client: 🏃 View run 37 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/9f86e8f4e59848aaa85b6c5e86af2acb.
# 2024/08/07 03:54:54 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:55:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run lyrical-bird-269 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/7a35cf0d2e42422aac9c26aee9d9c631.
# 2024/08/07 03:56:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run bustling-carp-199 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/610c6e8b56dc486bbdc0b3cf64de82af.
# 2024/08/07 03:56:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:56:31,258] Trial 39 finished with value: 0.7780742845440921 and parameters: {'n_estimators': 100, 'max_depth': 11, 'learning_rate': 0.046563836865432286, 'gamma': 0.37341192347573376, 'subsample': 0.9151062377090337, 'colsample_bytree': 0.6466728973227621}. Best is trial 36 with value: 0.719712403090776.
# 2024/08/07 03:56:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run 39 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/0c92654174e24bb1b3c10458f017d33e.
# 2024/08/07 03:56:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:57:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run nimble-crane-756 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/224afcce7bd04c589371969ee0b7d0f9.
# 2024/08/07 03:57:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:57:10,762] Trial 40 finished with value: 0.7769048202301618 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.0693540171229628, 'gamma': 1.8161604831395641, 'subsample': 0.6308095118555752, 'colsample_bytree': 0.6007730868745271}. Best is trial 36 with value: 0.719712403090776.
# 2024/08/07 03:57:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run 40 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/4ee3ee44d7614c68b7c4fe549e93ca40.
# 2024/08/07 03:57:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:57:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run bald-shark-78 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/b9fa5c68e0d6482b9304356ba9889cb8.
# 2024/08/07 03:57:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:57:55,669] Trial 41 finished with value: 0.7119804593187216 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.17633774244296488, 'gamma': 0.11848779234976205, 'subsample': 0.9714789175869125, 'colsample_bytree': 0.7633870281947578}. Best is trial 41 with value: 0.7119804593187216.
# 2024/08/07 03:57:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run 41 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/4ba4f3446816403aa4685332c42163b0.
# 2024/08/07 03:57:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:58:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run overjoyed-ape-565 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/f8ad0f9e193a40718415411a33c70b58.
# 2024/08/07 03:58:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:58:39,532] Trial 42 finished with value: 0.7146472840260368 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.1774203952625658, 'gamma': 0.12236758984647154, 'subsample': 0.9751398686623217, 'colsample_bytree': 0.7574835163483701}. Best is trial 41 with value: 0.7119804593187216.
# 2024/08/07 03:58:39 INFO mlflow.tracking._tracking_service.client: 🏃 View run 42 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/0aca15d51747465487fc5a7a0579b2ac.
# 2024/08/07 03:58:39 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 03:59:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run gregarious-shrike-41 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/d3d6b741bf6f49de8c48ff0383ebc4a0.
# 2024/08/07 03:59:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 03:59:13,639] Trial 43 finished with value: 0.7274162319352323 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.1688819418587535, 'gamma': 0.3214869899247461, 'subsample': 0.9425294372396062, 'colsample_bytree': 0.7608344807459189}. Best is trial 41 with value: 0.7119804593187216.
# 2024/08/07 03:59:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run 43 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/e2afbf3607db4a8bb858eb996af01f58.
# 2024/08/07 03:59:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 04:00:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run colorful-cod-117 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/8da9e1b995cb4aacaa34fa99dd18ea68.
# 2024/08/07 04:00:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 04:00:31,938] Trial 44 finished with value: 0.7058083203692072 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.19122423532688673, 'gamma': 0.10292583275263475, 'subsample': 0.7487956508006983, 'colsample_bytree': 0.7368400822551947}. Best is trial 44 with value: 0.7058083203692072.
# 2024/08/07 04:00:32 INFO mlflow.tracking._tracking_service.client: 🏃 View run 44 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/8740c32b753549a4b390fa1d6d00b88a.
# 2024/08/07 04:00:32 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 04:00:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run unleashed-gnat-407 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/e663304f52a644dc82ad0b8fb8b94f3f.
# ...
# 2024/08/07 04:32:31 INFO mlflow.tracking._tracking_service.client: 🏃 View run 70 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/c90555405bf442e58b709f5f352b9599.
# 2024/08/07 04:32:31 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 04:34:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run useful-ram-718 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/9c9dc04516d84770a0f439c51ab0cee1.
# 2024/08/07 04:34:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 04:34:08,491] Trial 71 finished with value: 0.7040841920725016 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.13419105843579526, 'gamma': 0.0012519969195702845, 'subsample': 0.6355711196710506, 'colsample_bytree': 0.8651069813759772}. Best is trial 68 with value: 0.7036919315543324.
# 2024/08/07 04:34:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run 71 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/d750c7e25e654a72acea734400c6ca66.
# 2024/08/07 04:34:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 04:35:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run sedate-pig-994 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/e6c23edc92e2469a950683dcaecb9938.
# 2024/08/07 04:35:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 04:35:40,077] Trial 72 finished with value: 0.7044822629559473 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.14817930305549573, 'gamma': 0.07062181612832297, 'subsample': 0.6347652389551228, 'colsample_bytree': 0.8691483841732384}. Best is trial 68 with value: 0.7036919315543324.
# 2024/08/07 04:35:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run 72 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/04f115c43ca746de9534dcfa80133467.
# 2024/08/07 04:35:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 04:37:11 INFO mlflow.tracking._tracking_service.client: 🏃 View run crawling-ray-808 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/29527561fd644938bb20f954eee72dcb.
# 2024/08/07 04:37:11 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 04:37:11,266] Trial 73 finished with value: 0.7051329578351438 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.144483477021277, 'gamma': 0.07261549541467828, 'subsample': 0.6293468843754618, 'colsample_bytree': 0.8735865049868551}. Best is trial 68 with value: 0.7036919315543324.
# 2024/08/07 04:37:11 INFO mlflow.tracking._tracking_service.client: 🏃 View run 73 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/4aa549667f4b4b14bc5a5084ef2dd561.
# 2024/08/07 04:37:11 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 04:38:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run delightful-moth-757 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/bcd6a4c99ac8428dac0b0ac22ff4ff3a.
# 2024/08/07 04:38:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 04:38:33,321] Trial 74 finished with value: 0.7087137494214032 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.12926032618981506, 'gamma': 0.2343145031564035, 'subsample': 0.650955893488815, 'colsample_bytree': 0.8529940955614502}. Best is trial 68 with value: 0.7036919315543324.
# 2024/08/07 04:38:33 INFO mlflow.tracking._tracking_service.client: 🏃 View run 74 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/04f1163a725540238c7c988a0de66b6a.
# 2024/08/07 04:38:33 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 04:39:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run secretive-tern-500 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/734026f94a3e4995bcdb357318048513.
# 2024/08/07 04:39:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [I 2024-08-07 04:39:59,750] Trial 75 finished with value: 0.7072625405224031 and parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.11636313289075446, 'gamma': 0.16364118572458555, 'subsample': 0.6604004420796024, 'colsample_bytree': 0.9033349779743964}. Best is trial 68 with value: 0.7036919315543324.
# 2024/08/07 04:39:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run 75 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/04ae8f3de8d244a6a59cdf9313326915.
# 2024/08/07 04:39:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# 2024/08/07 04:40:50 INFO mlflow.tracking._tracking_service.client: 🏃 View run indecisive-stoat-84 at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2/runs/f82ecb04f77d4f08824a55ee43deb5a1.
# 2024/08/07 04:40:50 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://spacefarm:HeetsCoffe1!@mlflow-izqyq2ng5q-du.a.run.app/#/experiments/2.
# [W 2024-08-07 04:40:50,733] Trial 76 failed with parameters: {'n_estimators': 200, 'max_depth': 11, 'learning_rate': 0.163703131346842, 'gamma': 0.07395101880096226, 'subsample': 0.6386823644574755, 'colsample_bytree': 0.8848185949324721} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/conda/envs/tensorflow/lib/python3.10/site-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "/var/tmp/ipykernel_15491/34023296.py", line 24, in objective
#     y_pred = cross_val_predict(model, x_train, y_train, cv=cv, n_jobs=-1) # <-- Use cross_val_predict
#   File "/opt/conda/envs/tensorflow/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/envs/tensorflow/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 1282, in cross_val_predict
#     predictions = parallel(
#   File "/opt/conda/envs/tensorflow/lib/python3.10/site-packages/sklearn/utils/parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#   File "/opt/conda/envs/tensorflow/lib/python3.10/site-packages/joblib/parallel.py", line 2007, in __call__
#     return output if self.return_generator else list(output)
#   File "/opt/conda/envs/tensorflow/lib/python3.10/site-packages/joblib/parallel.py", line 1650, in _get_outputs
#     yield from self._retrieve()
#   File "/opt/conda/envs/tensorflow/lib/python3.10/site-packages/joblib/parallel.py", line 1762, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
# [W 2024-08-07 04:40:50,740] Trial 76 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 75
#      71         return best_params, study.best_value
#      74 # --- Call the function to start the tuning process ---
# ---> 75 best_params, best_score = optimize_xgboost(x_train, y_train)
#
# Cell In[20], line 45, in optimize_xgboost(x_train, y_train, n_trials, experiment_name, n_splits)
#      42         return rmse
#      44 study = optuna.create_study(direction='minimize')
# ---> 45 study.optimize(objective, n_trials=n_trials, callbacks=[mlflow_callback])
#      47 # Get best parameters and train the final model
#      48 with mlflow.start_run(run_name="best_model"):
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/optuna/study/_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/optuna/study/_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/optuna/study/_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[20], line 24, in optimize_xgboost.<locals>.objective(trial)
#      22 model = xgb.XGBRegressor(**params)
#      23 cv = KFold(n_splits=n_splits, shuffle=False)  # Blocked cross-validation
# ---> 24 y_pred = cross_val_predict(model, x_train, y_train, cv=cv, n_jobs=-1) # <-- Use cross_val_predict
#      26 mse = mean_squared_error(y_train, y_pred)
#      27 rmse = np.sqrt(mse)
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:1282, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, params, pre_dispatch, method)
#    1279 # We clone the estimator to make sure that all the folds are
#    1280 # independent, and that it is pickle-able.
#    1281 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# -> 1282 predictions = parallel(
#    1283     delayed(_fit_and_predict)(
#    1284         clone(estimator),
#    1285         X,
#    1286         y,
#    1287         train,
#    1288         test,
#    1289         routed_params.estimator.fit,
#    1290         method,
#    1291     )
#    1292     for train, test in splits
#    1293 )
#    1295 inv_test_indices = np.empty(len(test_indices), dtype=int)
#    1296 inv_test_indices[test_indices] = np.arange(len(test_indices))
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/conda/envs/tensorflow/lib/python3.10/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
# tuning deep learning models
